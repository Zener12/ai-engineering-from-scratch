# %%
import random
# %timeit arr = [random.randint(1, 100000) for i in range(100000)]
# Out:
# 50.2 ms ± 1.57 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
import numpy as np
# %timeit arrr = np.random.randint(1, 100000, size=100000)
# Out:
# 931 μs ± 16.4 μs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %%
import pandas as pd
df = pd.DataFrame({
    "name": ["Alice", "Bob", "Charlie"],
    "score": [85, 92, 78],
    "age": [23, 25, 22]
})
df.to_csv("test.csv", index=False)
df2 = pd.read_csv("test.csv")
df2
# Out:
#       name  score  age
# 0    Alice     85   23
# 1      Bob     92   25
# 2  Charlie     78   22

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
df.plot(x='name', y='score', kind='bar')
plt.title("Scores")
plt.show()
